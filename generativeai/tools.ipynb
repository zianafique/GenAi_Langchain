# %% [markdown]
# ### TOOLS

# %%
import os
from langchain.chat_models import init_chat_model

# Fix env variable
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model= init_chat_model("groq:llama-3.1-8b-instant")

response = model.invoke("What is current AI news? Just the headlines.")

print(response.content)
# Out:
# Here are some current AI news headlines:
#
# 1. **Microsoft Unveils AI-Powered Bing with More Advanced Chat Features**: Microsoft has released an upgraded version of its search engine, featuring a more advanced AI chatbot.
#
# 2. **Google Launches Bard AI Model, Competing with ChatGPT**: Google has released its AI model, Bard, which is expected to compete with the popular ChatGPT chatbot.
#
# 3. **OpenAI Raises $10 Billion Funding Round for AI Research**: OpenAI has secured a $10 billion funding round to continue its AI research and development.
#
# 4. **AI-Powered Chatbots Pose Risks to Mental Health, Experts Warn**: Experts have warned that the increasing use of AI-powered chatbots may pose risks to mental health and well-being.
#
# 5. **Amazon Introduces AI-Powered Virtual Assistant for Businesses**: Amazon has released a new AI-powered virtual assistant for businesses, designed to streamline customer service and operations.
#
# 6. **China Unveils AI-Powered Robot that Can Assist with Medical Procedures**: China has unveiled a new AI-powered robot that can assist with medical procedures, such as surgery and patient diagnosis.
#
# 7. **Google's AI Researcher Calls for Greater Transparency in AI Development**: A Google researcher has called for greater transparency in AI development, citing concerns over bias and accountability.
#
# 8. **AI-Powered Cybersecurity System Detects 99% of Threats**: A new AI-powered cybersecurity system has been developed, capable of detecting 99% of cyber threats.
#
# 9. **Facebook's AI Model Can Generate High-Quality Images from Text Descriptions**: Facebook has developed an AI model that can generate high-quality images from text descriptions, opening up new possibilities for creative applications.
#
# 10. **US Military Deploys AI-Powered Drones for Surveillance**: The US military has deployed AI-powered drones for surveillance and reconnaissance missions, marking a significant shift in military technology.
#
# Please note that these headlines are subject to change and may not be up-to-date.

# %%
from google.generativeai import list_models

for m in list_models():
    print(m.name)

# %%
#Tools

from langchain.tools import tool

@tool
def get_weather(location: str) -> str:
    """Get the weather at a location"""
    return f"It's sunny in {location}"

model_with_tools=model.bind_tools([get_weather])

# %%
response=model_with_tools.invoke("What is weather in Dhaka")
print(response)

# %%
response.tool_calls
# Out:
# [{'name': 'get_weather',
#   'args': {'location': 'Dhaka'},
#   'id': '8c301b54-98dc-42ae-9dc5-ab8d85a18d45',
#   'type': 'tool_call'}]

# %% [markdown]
# ### Tool execution loop

# %%
# Step 1: Model generates tool calls
messages = [{"role": "user", "content": "What's the weather in Boston?"}]
ai_msg = model_with_tools.invoke(messages)
messages.append(ai_msg)

# Step 2: Execute tools and collect results
for tool_call in ai_msg.tool_calls:
    # Execute the tool with the generated arguments
    tool_result = get_weather.invoke(tool_call)
    messages.append(tool_result)

# Step 3: Pass results back to model for final response
final_response = model_with_tools.invoke(messages)
print(final_response.text)
# "The current weather in Boston is 72°F and sunny."

# %%
messages
# Out:
# [{'role': 'user', 'content': "What's the weather in Boston?"},
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'myebcyach', 'function': {'arguments': '{"location":"Boston"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 219, 'total_tokens': 233, 'completion_time': 0.023118466, 'completion_tokens_details': None, 'prompt_time': 0.013674263, 'prompt_tokens_details': None, 'queue_time': 0.201401152, 'total_time': 0.036792729}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019da055-22a4-7fb0-8a9f-c0971e16d0a0-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Boston'}, 'id': 'myebcyach', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 219, 'output_tokens': 14, 'total_tokens': 233}),
#  ToolMessage(content="It's sunny in Boston", name='get_weather', tool_call_id='myebcyach')]

# %%
model_with_tools
# Out:
# RunnableBinding(bound=ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000210B388BB60>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000210B4A946E0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None), kwargs={'tools': [{'type': 'function', 'function': {'name': 'get_weather', 'description': 'Get the weather at a location', 'parameters': {'properties': {'location': {'type': 'string'}}, 'required': ['location'], 'type': 'object'}}}]}, config={}, config_factories=[])
